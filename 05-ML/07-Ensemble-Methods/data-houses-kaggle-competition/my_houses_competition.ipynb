# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# Basics
import numpy as np
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load data
# Note that the Train set will have one more column than the Test set, since the former includes the target.

# %% [markdown]
# #### Train

# %%
data = pd.read_csv("data/train.csv", index_col="Id")
display(data.describe())
display(data.head())

print("\nShape", data.shape)
print("\n Dtypes")
display(data.dtypes.value_counts())
print("\nDuplicates", data.duplicated().sum())
print("\nNulls")
display(data.isnull().sum().sort_values(ascending=False).head(20))

print("Columns:", data.columns)
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# ### Split into X and Y

# %%
X = data.drop("SalePrice", axis=1)
y = data["SalePrice"]

print(X.shape, y.shape)
# Out:
# (1460, 79) (1460,)

# %% [markdown]
# ## Initial data analysis

# %%
data.dtypes.value_counts()
# Out:
# object     43
# int64      34
# float64     3
# dtype: int64

# %%
X_cat = data.select_dtypes("object")
X_cat.shape
# Out:
# (1460, 43)

# %%
X_num = data.select_dtypes("number")
X_num.shape
# Out:
# (1460, 37)

# %% [markdown]
# #### Duplicate values

# %%
print("Train", data.duplicated().sum())

if data.duplicated().sum() == 0:
    print("Neither train nor test data contain duplicate value.")
# Out:
# Train 0
# Neither train nor test data contain duplicate value.

# %% [markdown]
# #### Empty values

# %%
pd.DataFrame(data.isnull().sum().sort_values(ascending=False)).head(40)
# Out:
#                   0
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
# LotFrontage     259
# GarageYrBlt      81
# GarageCond       81
# GarageType       81
# GarageFinish     81
# GarageQual       81
# BsmtFinType2     38
# BsmtExposure     38
# BsmtQual         37
# BsmtCond         37
# BsmtFinType1     37
# MasVnrArea        8
# MasVnrType        8
# Electrical        1
# Id                0
# Functional        0
# Fireplaces        0
# KitchenQual       0
# KitchenAbvGr      0
# BedroomAbvGr      0
# HalfBath          0
# FullBath          0
# BsmtHalfBath      0
# TotRmsAbvGrd      0
# GarageCars        0
# GrLivArea         0
# GarageArea        0
# PavedDrive        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# PoolArea          0
# MiscVal           0

# %%
pd.DataFrame(data.isnull().sum().sort_values(ascending=False)).reset_index().head(20)
# Out:
#            index     0
# 0         PoolQC  1453
# 1    MiscFeature  1406
# 2          Alley  1369
# 3          Fence  1179
# 4    FireplaceQu   690
# 5    LotFrontage   259
# 6    GarageYrBlt    81
# 7     GarageCond    81
# 8     GarageType    81
# 9   GarageFinish    81
# 10    GarageQual    81
# 11  BsmtFinType2    38
# 12  BsmtExposure    38
# 13      BsmtQual    37
# 14      BsmtCond    37
# 15  BsmtFinType1    37
# 16    MasVnrArea     8
# 17    MasVnrType     8
# 18    Electrical     1
# 19            Id     0

# %% [markdown]
# ##### PoolQC
# Almost all values are empty for train and test. Let's remove the column.

# %%
data["PoolQC"].value_counts(dropna=False)
# Out:
# NaN    1453
# Gd        3
# Ex        2
# Fa        2
# Name: PoolQC, dtype: int64

# %%
data.drop("PoolQC", axis=1, inplace=True)

print(data.shape)
# Out:
# (1460, 80)

# %% [markdown]
# ##### MiscFeature
# Almost all values are empty for train and test. Let's remove the column.

# %%
data["MiscFeature"].value_counts(dropna=False)
# Out:
# NaN     1406
# Shed      49
# Gar2       2
# Othr       2
# TenC       1
# Name: MiscFeature, dtype: int64

# %%
data.drop("MiscFeature", axis=1, inplace=True)

print(data.shape)
# Out:
# (1460, 79)
